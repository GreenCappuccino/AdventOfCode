# %%
print("hello")
# Out:
# hello

# %%
calories = []
for elf in open("data.txt", "r").read().split("\n\n"):
    calories.append(sum([int(line) for line in elf.splitlines()]))

# %%
calories
# Out:
# [34142,
#  54868,
#  28046,
#  64877,
#  39885,
#  31499,
#  48244,
#  51070,
#  62852,
#  43189,
#  35931,
#  51405,
#  48845,
#  41252,
#  48313,
#  27971,
#  15944,
#  39628,
#  41417,
#  46328,
#  50713,
#  54172,
#  56674,
#  45535,
#  50837,
#  46690,
#  53721,
#  54196,
#  59604,
#  42049,
#  7928,
#  65880,
#  51198,
#  49129,
#  69102,
#  34143,
#  48757,
#  50181,
#  38201,
#  39634,
#  50611,
#  40729,
#  39611,
#  48665,
#  45945,
#  57291,
#  39259,
#  57842,
#  42990,
#  36286,
#  20304,
#  29630,
#  48012,
#  46876,
#  41538,
#  60284,
#  45029,
#  36768,
#  45299,
#  54524,
#  45766,
#  45838,
#  49278,
#  56044,
#  57529,
#  57984,
#  48283,
#  38369,
#  49879,
#  33815,
#  51003,
#  51344,
#  49383,
#  48317,
#  56133,
#  63368,
#  13208,
#  55640,
#  32857,
#  43769,
#  51069,
#  55258,
#  42197,
#  48207,
#  56062,
#  62252,
#  50734,
#  52213,
#  49847,
#  36254,
#  62988,
#  64848,
#  59507,
#  35033,
#  57287,
#  57617,
#  49808,
#  36500,
#  47962,
#  52265,
# ...

# %%
max(calories)
# Out:
# 75501

# %%
calories.sort(reverse=True)

# %%
sum(calories[0:3])
# Out:
# 215594

# %%
calories
# Out:
# [75501,
#  70096,
#  69997,
#  69619,
#  69102,
#  69009,
#  67021,
#  65880,
#  65024,
#  64877,
#  64848,
#  64294,
#  63368,
#  62988,
#  62852,
#  62252,
#  62103,
#  61968,
#  61722,
#  61668,
#  60379,
#  60284,
#  59735,
#  59604,
#  59507,
#  59477,
#  59403,
#  59314,
#  58963,
#  58941,
#  58334,
#  58257,
#  58146,
#  57984,
#  57842,
#  57663,
#  57617,
#  57529,
#  57291,
#  57287,
#  57025,
#  56921,
#  56813,
#  56799,
#  56674,
#  56484,
#  56262,
#  56147,
#  56133,
#  56062,
#  56044,
#  56004,
#  55759,
#  55750,
#  55640,
#  55604,
#  55289,
#  55258,
#  55020,
#  54988,
#  54868,
#  54717,
#  54686,
#  54542,
#  54524,
#  54437,
#  54234,
#  54196,
#  54172,
#  53721,
#  53707,
#  53567,
#  53471,
#  53438,
#  53427,
#  53363,
#  53031,
#  52998,
#  52910,
#  52810,
#  52291,
#  52265,
#  52213,
#  52064,
#  51862,
#  51823,
#  51789,
#  51710,
#  51679,
#  51672,
#  51405,
#  51403,
#  51395,
#  51344,
#  51288,
#  51198,
#  51170,
#  51070,
#  51069,
#  51003,
# ...
